# %%
from PIL import Image

# %%
img = Image.open("image.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=383x383 at 0x10360FB70>

# %%
img.save("temp.png")
print(img.getpixel((100, 100)))
# Out:
# (186, 186, 186, 255)

# %%
dim = (100, 100, 400, 400)

# %%
crop_img = img.crop(dim)

# %%
display(img)
display(crop_img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=383x383 at 0x10360FB70>
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x103623400>
